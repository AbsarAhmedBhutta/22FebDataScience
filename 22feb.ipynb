# %%
import pandas as pd

# %%
df = pd.read_csv('SuperStoreOrders.csv')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  31-12-2014  4/1/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  31-12-2014  5/1/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  31-12-2014  2/1/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  31-12-2014  6/1/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  31-12-2014  4/1/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns.tolist()
# Out:
# ['order_id',
#  'order_date',
#  'ship_date',
#  'ship_mode',
#  'customer_name',
#  'segment',
#  'state',
#  'country',
#  'market',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name',
#  'sales',
#  'quantity',
#  'discount',
#  'profit',
#  'shipping_cost',
#  'order_priority',
#  'year']

# %%
df.duplicated(['order_id',
 'order_date',
 'ship_date',
 'ship_mode',
 'customer_name',
 'segment',
 'state',
 'country',
 'market',
 'region',
 'product_id',
 'category',
 'sub_category',
 'product_name',
 'sales',
 'quantity',
 'discount',
 'profit',
 'shipping_cost',
 'order_priority',
 'year'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
# sorted_df = df.groupby('quantity').apply(lambda x: x.sort_values(['quantity']))
# # print the sorted DataFrame
# sorted_df

sorted = df.sort_values(['quantity'])
sorted.to_csv('Sort.csv')

# %%
# create a subset of the DataFrame with sales between 10 and 400

# to tackle this TypeError: '>' not supported between instances of 'str' and 'int' using:

# df['sales'] = pd.to_numeric(df['sales'], errors='coerce')
sales = df[(df['sales'] >= 10) & (df['sales'] <= 400)]

sales.to_csv('sales_between_10_and_400.csv')

# %%
# Add a new column profit - shipping cost name it gross profit

df['gross_profit'] = df['profit']-df['shipping_cost']
df.to_csv('new_col_gross_profit.csv')

# %%
#Find out which products not available per region


all_products = df['product_name'].unique()

grouped = df.groupby('region')

not_available_df = pd.DataFrame(columns=['region', 'not_available_products'])

for region_name, region_df in grouped:
    available = region_df['product_name'].unique()
    not_available = set(all_products) - set(available)
    region_data = {'region': region_name, 'not_available_products': not_available}
    not_available_df = pd.concat([not_available_df, pd.DataFrame([region_data])], ignore_index=True)

not_available_df.to_csv('notavailable_per_region.csv')
